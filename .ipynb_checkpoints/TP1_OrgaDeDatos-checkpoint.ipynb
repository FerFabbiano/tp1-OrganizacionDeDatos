# %%
# !pip install squarify
import pandas as pd
import numpy as np
import seaborn as sns
import squarify # pip install squarify
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: squarify in /home/fernando/anaconda3/lib/python3.7/site-packages (0.4.3)

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 100

# %%
#from pydrive.auth import GoogleAuth
#from pydrive.drive import GoogleDrive
#from google.colab import auth
#from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
#auth.authenticate_user()
#gauth = GoogleAuth()
#gauth.credentials = GoogleCredentials.get_application_default()
#drive = GoogleDrive(gauth)

#from google.colab import files 
#uploaded = files.upload()

# %%
#link = 'https://drive.google.com/file/d/1dOMHOcmTuEUmN6-OwaXzxmwtrSglE4fC/view'
#id = link.split("/")[-2] 
  
#downloaded = drive.CreateFile({'id':id})  
#downloaded.GetContentFile('Entrenamieto_ECI_2020.csv')

# %%
pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

entrenamientoDf = pd.read_csv('Entrenamieto_ECI_2020.csv')
entrenamientoDf.head(100)
# Out:
#        ID    Region       Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0   27761      EMEA            None                                   1
# 1   27760      EMEA            None                                   0
# 2   27446  Americas      NW America                                   0
# 3   16808  Americas      NW America                                   1
# 4   16805  Americas      NW America                                   1
# 5   16802  Americas      NW America                                   1
# 6   16799  Americas      NW America                                   1
# 7   27455  Americas      NW America                                   1
# 8   24353     Japan            None                                   1
# 9   24355     Japan            None                                   1
# 10  24356     Japan            None                                   1
# 11  24357     Japan            None                                   1
# 12  24358     Japan            None                                   1
# 13  24420     Japan            None                                   1
# 14  24422     Japan            None                                   1
# 15  24423     Japan            None                                   1
# 16  24424     Japan            None                                   1
# 17  24425     Japan            None                                   1
# 18  24366     Japan            None                                   1
# 19  24367     Japan            None                                   1
# 20  24368     Japan            None                                   1
# 21  24369     Japan            None                                   1
# 22  24370     Japan            None                                   1
# 23  28524      APAC           India                                   1
# 24   4915      APAC           India                                   1
# 25  24384     Japan            None                                   1
# 26  24385     Japan            None                                   1
# 27  24386     Japan            None                                   1
# 28  24389     Japan            None                                   1
# 29  24390     Japan            None                                   1
# 30  24391     Japan            None                                   1
# 31  24359     Japan            None                                   1
# 32  24360     Japan            None                                   1
# 33  24361     Japan            None                                   1
# 34  24362     Japan            None                                   1
# 35  24363     Japan            None                                   1
# 36  24364     Japan            None                                   1
# 37  24397     Japan            None                                   1
# 38  24398     Japan            None                                   1
# 39  24400     Japan            None                                   1
# 40  24401     Japan            None                                   1
# 41  24402     Japan            None                                   1
# 42  24403     Japan            None                                   1
# 43  24404     Japan            None                                   1
# 44  24377     Japan            None                                   1
# 45  24378     Japan            None                                   1
# 46  24379     Japan            None                                   1
# 47  24380     Japan            None                                   1
# 48  24381     Japan            None                                   1
# 49  24382     Japan            None                                   1
# 50  24383     Japan            None                                   1
# 51  24392     Japan            None                                   1
# 52  24393     Japan            None                                   1
# 53  24394     Japan            None                                   1
# 54  24395     Japan            None                                   1
# 55  24396     Japan            None                                   1
# 56  24405     Japan            None                                   1
# 57  24406     Japan            None                                   1
# 58  24407     Japan            None                                   1
# 59  24408     Japan            None                                   1
# 68           12/10/2015       None        United Kingdom  Account_Name_1438
# 69            7/27/2013   Source_9               Germany   Account_Name_533
# 70            7/27/2013       None        United Kingdom  Account_Name_1988
# 71            7/27/2013       None        United Kingdom  Account_Name_1988
# 72            7/27/2013       None        United Kingdom  Account_Name_1988
# 73            7/27/2013       None        United Kingdom   Account_Name_121
# 74            7/27/2013       None        United Kingdom   Account_Name_121
# 75            7/27/2013       None        United Kingdom   Account_Name_121
# 76            7/27/2013       None        United Kingdom   Account_Name_121
# 77           12/14/2015       None                 India  Account_Name_1732
# 78            12/8/2015       None  United Arab Emirates   Account_Name_583
# 79           12/20/2013       None               Germany   Account_Name_606
# 80           12/20/2013       None               Germany   Account_Name_606
# 81            7/27/2013   Source_9                Greece  Account_Name_1511
# 82            7/27/2013   Source_7        United Kingdom  Account_Name_1108
# 83            7/20/2015   Source_3           Switzerland  Account_Name_1459
# 84            12/4/2015       None               Germany   Account_Name_586
# 85           12/17/2015       None               Austria   Account_Name_686
# 86           12/17/2015       None               Austria   Account_Name_686
# 87           12/17/2015       None               Austria   Account_Name_686
# 88            4/20/2015       None                 Japan  Account_Name_1888
# 89            4/20/2015       None                 Japan  Account_Name_1888
# 90            4/20/2015       None                 Japan  Account_Name_1888
# 91            4/20/2015       None                 Japan  Account_Name_1888
# 92            4/20/2015       None                 Japan  Account_Name_1888
# 93            4/20/2015       None                 Japan  Account_Name_1888
# 94            4/20/2015       None                 Japan  Account_Name_1888
# 95            4/20/2015       None                 Japan  Account_Name_1888
# 96            4/20/2015       None                 Japan  Account_Name_1888
# 97            4/20/2015       None                 Japan  Account_Name_1888
# 98            4/20/2015       None                 Japan  Account_Name_1888
# 99            4/20/2015       None                 Japan  Account_Name_1888
#
#           Opportunity_Name  Opportunity_ID Sales_Contract_No   Account_Owner  \
# 0   Opportunity_Name_12598               0              None  Person_Name_51
# 1   Opportunity_Name_12600               1                39  Person_Name_51
# 2     Opportunity_Name_469               2               760  Person_Name_64
# 3     Opportunity_Name_415               3              None   Person_Name_8
# 4     Opportunity_Name_851               4              None   Person_Name_8
# 5     Opportunity_Name_939               5              None   Person_Name_8
# 6    Opportunity_Name_1618               6              None   Person_Name_8
# 7    Opportunity_Name_8227               7              None  Person_Name_64
# 8    Opportunity_Name_6151               8              None  Person_Name_50
# 9    Opportunity_Name_6151               8              None  Person_Name_50
# 10   Opportunity_Name_6151               8              None  Person_Name_50
# 11   Opportunity_Name_6151               8              None  Person_Name_50
# 12   Opportunity_Name_6151               8              None  Person_Name_50
# 13   Opportunity_Name_6817               9              None  Person_Name_50
# 14   Opportunity_Name_6817               9              None  Person_Name_50
# 15   Opportunity_Name_6817               9              None  Person_Name_50
# 16   Opportunity_Name_6817               9              None  Person_Name_50
# 17   Opportunity_Name_6817               9              None  Person_Name_50
# 18   Opportunity_Name_5971              10              None  Person_Name_50
# 19   Opportunity_Name_5971              10              None  Person_Name_50
# 20   Opportunity_Name_5971              10              None  Person_Name_50
# 21   Opportunity_Name_5971              10              None  Person_Name_50
# 22   Opportunity_Name_5971              10              None  Person_Name_50
# 23   Opportunity_Name_7036              11                25  Person_Name_60
# 24   Opportunity_Name_3858              12              None  Person_Name_49
# 25   Opportunity_Name_4863              13              None  Person_Name_50
# 26   Opportunity_Name_4863              13              None  Person_Name_50
# 27   Opportunity_Name_4863              13              None  Person_Name_50
# 28   Opportunity_Name_4863              13              None  Person_Name_50
# 29   Opportunity_Name_4863              13              None  Person_Name_50
# 30   Opportunity_Name_4863              13              None  Person_Name_50
# 31   Opportunity_Name_7004              14              None  Person_Name_50
# 32   Opportunity_Name_7004              14              None  Person_Name_50
# 33   Opportunity_Name_7004              14              None  Person_Name_50
# 34   Opportunity_Name_7004              14              None  Person_Name_50
# 35   Opportunity_Name_7004              14              None  Person_Name_50
# 36   Opportunity_Name_7004              14              None  Person_Name_50
# 37   Opportunity_Name_2353              15              None  Person_Name_50
# 38   Opportunity_Name_2353              15              None  Person_Name_50
# 39   Opportunity_Name_2353              15              None  Person_Name_50
# 40   Opportunity_Name_2353              15              None  Person_Name_50
# 41   Opportunity_Name_2353              15              None  Person_Name_50
# 42   Opportunity_Name_2353              15              None  Person_Name_50
# 43   Opportunity_Name_2353              15              None  Person_Name_50
# 44   Opportunity_Name_2202              16              None  Person_Name_50
# 45   Opportunity_Name_2202              16              None  Person_Name_50
# 46   Opportunity_Name_2202              16              None  Person_Name_50
# 47   Opportunity_Name_2202              16              None  Person_Name_50
# 48   Opportunity_Name_2202              16              None  Person_Name_50
# 49   Opportunity_Name_2202              16              None  Person_Name_50
# 50   Opportunity_Name_2202              16              None  Person_Name_50
# 51   Opportunity_Name_6594              17              None  Person_Name_50
# 52   Opportunity_Name_6594              17              None  Person_Name_50
# 53   Opportunity_Name_6594              17              None  Person_Name_50
# 54   Opportunity_Name_6594              17              None  Person_Name_50
# 55   Opportunity_Name_6594              17              None  Person_Name_50
# 56   Opportunity_Name_6849              18              None  Person_Name_50
# 57   Opportunity_Name_6849              18              None  Person_Name_50
# 58   Opportunity_Name_6849              18              None  Person_Name_50
# 59   Opportunity_Name_6849              18              None  Person_Name_50
# 60   Opportunity_Name_6849              18              None  Person_Name_50
# 61   Opportunity_Name_6849              18              None  Person_Name_50
# 62   Opportunity_Name_9078              19              None   Person_Name_2
# 63   Opportunity_Name_4062              20              None  Person_Name_13
# 64   Opportunity_Name_6397              21              None   Person_Name_8
# 65   Opportunity_Name_5583              22              None  Person_Name_50
# 66   Opportunity_Name_2804              23              None  Person_Name_18
# 67   Opportunity_Name_2801              24              None  Person_Name_18
# 68  Opportunity_Name_10106              25              None  Person_Name_18
# 69   Opportunity_Name_7191              26              None  Person_Name_13
# 70  Opportunity_Name_12137              27              None  Person_Name_18
# 71  Opportunity_Name_12137              27              None  Person_Name_18
# 72  Opportunity_Name_12137              27              None  Person_Name_18
# 73   Opportunity_Name_2052              28              None  Person_Name_18
# 74   Opportunity_Name_2052              28              None  Person_Name_18
# 75   Opportunity_Name_2052              28              None  Person_Name_18
# 76   Opportunity_Name_2052              28              None  Person_Name_18
# 77  Opportunity_Name_11272              29                 8  Person_Name_60
# 78   Opportunity_Name_3913              30              None  Person_Name_39
# 79   Opportunity_Name_4536              31              None  Person_Name_13
# 80   Opportunity_Name_4536              31              None  Person_Name_13
# 81    Opportunity_Name_557              32              None  Person_Name_39
# 82   Opportunity_Name_6359              33              None  Person_Name_18
# 83   Opportunity_Name_4755              34               119  Person_Name_13
# 84   Opportunity_Name_4489              35              None  Person_Name_13
# 85   Opportunity_Name_4090              36                40  Person_Name_13
# 86   Opportunity_Name_4090              36                40  Person_Name_13
# 87   Opportunity_Name_4090              36                40  Person_Name_13
# 88   Opportunity_Name_6590              37              None  Person_Name_50
# 89   Opportunity_Name_6590              37              None  Person_Name_50
# 90   Opportunity_Name_6590              37              None  Person_Name_50
# 91   Opportunity_Name_6590              37              None  Person_Name_50
# 92   Opportunity_Name_6590              37              None  Person_Name_50
# 93   Opportunity_Name_6788              38              None  Person_Name_50
# 94   Opportunity_Name_6788              38              None  Person_Name_50
# 95   Opportunity_Name_6788              38              None  Person_Name_50
# 96   Opportunity_Name_6788              38              None  Person_Name_50
# 97   Opportunity_Name_6788              38              None  Person_Name_50
# 98   Opportunity_Name_6788              38              None  Person_Name_50
# 99   Opportunity_Name_6589              39              None  Person_Name_50
#
#    Opportunity_Owner    Account_Type     Opportunity_Type   Quote_Type  \
# 0     Person_Name_18  Account_Type_2   Opportunity_Type_1  Non Binding
# 1     Person_Name_20  Account_Type_2   Opportunity_Type_1  Non Binding
# 2      Person_Name_8  Account_Type_5   Opportunity_Type_1  Non Binding
# 3      Person_Name_8  Account_Type_5  Opportunity_Type_19  Non Binding
# 4      Person_Name_8  Account_Type_5  Opportunity_Type_19  Non Binding
# 5      Person_Name_8  Account_Type_5  Opportunity_Type_19  Non Binding
# 6      Person_Name_8  Account_Type_5  Opportunity_Type_19  Non Binding
# 7      Person_Name_8  Account_Type_5   Opportunity_Type_1  Non Binding
# 8     Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 9     Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 10    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 11    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 12    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 13    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 14    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 15    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 16    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 17    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 18    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 19    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 20    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 21    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 22    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 23    Person_Name_49  Account_Type_2  Opportunity_Type_19  Non Binding
# 24    Person_Name_49  Account_Type_2   Opportunity_Type_1  Non Binding
# 25    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 26    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 27    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 28    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 29    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 30    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 31    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 32    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 33    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 34    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 35    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 36    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 37    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 38    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 39    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 40    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 41    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 42    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 43    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 44    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 45    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 46    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 47    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 48    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 49    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 50    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 51    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 52    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 53    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 54    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 55    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 56    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 57    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 58    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 59    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 60    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 61    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 62    Person_Name_39  Account_Type_0   Opportunity_Type_7  Non Binding
# 63    Person_Name_13  Account_Type_0   Opportunity_Type_8  Non Binding
# 64     Person_Name_8  Account_Type_5   Opportunity_Type_7  Non Binding
# 65    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 66    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 67    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 68    Person_Name_18  Account_Type_0  Opportunity_Type_19  Non Binding
# 69    Person_Name_13  Account_Type_0   Opportunity_Type_1  Non Binding
# 70    Person_Name_18  Account_Type_0   Opportunity_Type_2  Non Binding
# 71    Person_Name_18  Account_Type_0   Opportunity_Type_2  Non Binding
# 72    Person_Name_18  Account_Type_0   Opportunity_Type_2  Non Binding
# 73    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 74    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 75    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 76    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 77    Person_Name_60  Account_Type_2   Opportunity_Type_7  Non Binding
# 78    Person_Name_39            None   Opportunity_Type_1  Non Binding
# 79    Person_Name_13  Account_Type_5  Opportunity_Type_19  Non Binding
# 80    Person_Name_13  Account_Type_5  Opportunity_Type_19  Non Binding
# 81    Person_Name_23  Account_Type_0   Opportunity_Type_1  Non Binding
# 82    Person_Name_18  Account_Type_0   Opportunity_Type_1  Non Binding
# 83    Person_Name_13  Account_Type_2   Opportunity_Type_1  Non Binding
# 84    Person_Name_13  Account_Type_2  Opportunity_Type_19  Non Binding
# 85    Person_Name_13  Account_Type_0   Opportunity_Type_7  Non Binding
# 86    Person_Name_13  Account_Type_0   Opportunity_Type_7  Non Binding
# 87    Person_Name_13  Account_Type_0   Opportunity_Type_7  Non Binding
# 88    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 89    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 90    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 91    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 92    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 93    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 94    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 95    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 96    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 97    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 98    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
# 99    Person_Name_50  Account_Type_2   Opportunity_Type_7  Non Binding
#
#       Delivery_Terms Opportunity_Created_Date  Brand    Product_Type    Size  \
# 0   Delivery_Terms_2                12/7/2015   None            None    None
# 1   Delivery_Terms_2                12/7/2015   None            None    None
# 2   Delivery_Terms_4                12/8/2015   None            None    None
# 3   Delivery_Terms_1                12/8/2015  Other  Product_Type_0  Size_4
# 4   Delivery_Terms_1                12/8/2015  Other  Product_Type_0  Size_4
# 5   Delivery_Terms_1                12/8/2015  Other  Product_Type_0  Size_4
# 6   Delivery_Terms_4                12/8/2015   None            None    None
# 7   Delivery_Terms_4                12/9/2015   None            None    None
# 8   Delivery_Terms_4                12/9/2015   None            None    None
# 9   Delivery_Terms_4                12/9/2015   None            None    None
# 10  Delivery_Terms_4                12/9/2015   None            None    None
# 11  Delivery_Terms_4                12/9/2015   None            None    None
# 12  Delivery_Terms_4                12/9/2015   None            None    None
# 13  Delivery_Terms_4                12/9/2015   None            None    None
# 14  Delivery_Terms_4                12/9/2015   None            None    None
# 15  Delivery_Terms_4                12/9/2015   None            None    None
# 16  Delivery_Terms_4                12/9/2015   None            None    None
# 17  Delivery_Terms_4                12/9/2015   None            None    None
# 18  Delivery_Terms_4                12/9/2015   None            None    None
# ...
# 77  2016 - 1               Q1           2016                  NaT    0
# 78  2016 - 4               Q2           2016                  NaT    0
# 79  2016 - 5               Q2           2016                  NaT   20
# 80  2016 - 7               Q3           2016                  NaT   20
# 81  2016 - 2               Q1           2016                  NaT    1
# 82  2016 - 1               Q1           2016                  NaT    0
# 54                   JPY           140,000.00                           JPY
# 55                   JPY           304,200.00                           JPY
# 56                   JPY             9,600.00                           JPY
# 57                   JPY            31,200.00                           JPY
# 58                   JPY             4,400.00                           JPY
# 59                   JPY             6,200.00                           JPY
# 60                   JPY           140,000.00                           JPY
# 61                   JPY           385,320.00                           JPY
# 62                   EUR           259,875.00                           EUR
# 63                   EUR           103,350.00                           EUR
# 64                   USD         3,184,974.00                           USD
# 65                   JPY           243,360.00                           JPY
# 66                   EUR           214,500.00                           EUR
# 67                   EUR           214,500.00                           EUR
# 68                   EUR         1,556,587.50                           EUR
# 69                   EUR           549,780.00                           EUR
# 70                   EUR           107,250.00                           EUR
# 71                   EUR           103,125.00                           EUR
# 72                   EUR           107,250.00                           EUR
# 73                   EUR           107,250.00                           EUR
# 74                   EUR           107,250.00                           EUR
# 75                   EUR           107,250.00                           EUR
# 76                   EUR           107,250.00                           EUR
# 77                   USD             3,920.00                           USD
# 78                   USD             7,695.00                           USD
# 79                   EUR         9,937,200.00                           EUR
# 80                   EUR         9,937,200.00                           EUR
# 81                   EUR           510,510.00                           EUR
# 82                   EUR           105,300.00                           EUR
# 83                   EUR           364,905.00                           EUR
# 84                   EUR         5,618,160.00                           EUR
# 85                   EUR            56,160.00                           EUR
# 86                   EUR            20,250.00                           EUR
# 87                   EUR            27,540.00                           EUR
# 88                   JPY            23,400.00                           JPY
# 89                   JPY             4,400.00                           JPY
# 90                   JPY             6,200.00                           JPY
# 91                   JPY           140,000.00                           JPY
# 92                   JPY           425,880.00                           JPY
# 93                   JPY             1,600.00                           JPY
# 94                   JPY            31,200.00                           JPY
# 95                   JPY             4,400.00                           JPY
# 96                   JPY             6,200.00                           JPY
# 97                   JPY           300,000.00                           JPY
# 98                   JPY           811,200.00                           JPY
# 99                   JPY            15,600.00                           JPY
#
#     Total_Taxable_Amount        Stage       Prod_Category_A
# 0           5,272,800.00  Closed Lost  Prod_Category_A_None
# 1              48,230.00   Closed Won  Prod_Category_A_None
# 2              83,865.60   Closed Won  Prod_Category_A_None
# 3           7,421,881.50  Closed Lost  Prod_Category_A_None
# 4          13,357,192.50  Closed Lost  Prod_Category_A_None
# 5          14,838,277.50  Closed Lost  Prod_Category_A_None
# 6           2,659,494.60  Closed Lost  Prod_Category_A_None
# 7              50,688.00   Closed Won  Prod_Category_A_None
# 8             470,400.00  Closed Lost  Prod_Category_A_None
# 9             470,400.00  Closed Lost  Prod_Category_A_None
# 10            470,400.00  Closed Lost  Prod_Category_A_None
# 11            470,400.00  Closed Lost  Prod_Category_A_None
# 12            470,400.00  Closed Lost  Prod_Category_A_None
# 13            559,320.00  Closed Lost  Prod_Category_A_None
# 14            559,320.00  Closed Lost  Prod_Category_A_None
# 15            559,320.00  Closed Lost  Prod_Category_A_None
# 16            559,320.00  Closed Lost  Prod_Category_A_None
# 17            559,320.00  Closed Lost  Prod_Category_A_None
# 18            579,600.00  Closed Lost  Prod_Category_A_None
# 19            579,600.00  Closed Lost  Prod_Category_A_None
# 20            579,600.00  Closed Lost  Prod_Category_A_None
# 21            579,600.00  Closed Lost  Prod_Category_A_None
# 22            579,600.00  Closed Lost  Prod_Category_A_None
# 23          1,621,851.00   Closed Won  Prod_Category_A_None
# 24            221,650.00  Closed Lost  Prod_Category_A_None
# 25          1,012,920.00  Closed Lost  Prod_Category_A_None
# 26          1,012,920.00  Closed Lost  Prod_Category_A_None
# 27          1,012,920.00  Closed Lost  Prod_Category_A_None
# 28          1,012,920.00  Closed Lost  Prod_Category_A_None
# 29          1,012,920.00  Closed Lost  Prod_Category_A_None
# 30          1,012,920.00  Closed Lost  Prod_Category_A_None
# 31            972,360.00  Closed Lost  Prod_Category_A_None
# 32            972,360.00  Closed Lost  Prod_Category_A_None
# 33            972,360.00  Closed Lost  Prod_Category_A_None
# 34            972,360.00  Closed Lost  Prod_Category_A_None
# 35            972,360.00  Closed Lost  Prod_Category_A_None
# 36            972,360.00  Closed Lost  Prod_Category_A_None
# 37          1,144,120.00  Closed Lost  Prod_Category_A_None
# 38          1,144,120.00  Closed Lost  Prod_Category_A_None
# 39          1,144,120.00  Closed Lost  Prod_Category_A_None
# 40          1,144,120.00  Closed Lost  Prod_Category_A_None
# 41          1,144,120.00  Closed Lost  Prod_Category_A_None
# 42          1,144,120.00  Closed Lost  Prod_Category_A_None
# 43          1,144,120.00  Closed Lost  Prod_Category_A_None
# 44          1,359,040.00  Closed Lost  Prod_Category_A_None
# 45          1,359,040.00  Closed Lost  Prod_Category_A_None
# 46          1,359,040.00  Closed Lost  Prod_Category_A_None
# 47          1,359,040.00  Closed Lost  Prod_Category_A_None
# 48          1,359,040.00  Closed Lost  Prod_Category_A_None
# 49          1,359,040.00  Closed Lost  Prod_Category_A_None
# 50          1,359,040.00  Closed Lost  Prod_Category_A_None
# 51            486,000.00  Closed Lost  Prod_Category_A_None
# 52            486,000.00  Closed Lost  Prod_Category_A_None
# 53            486,000.00  Closed Lost  Prod_Category_A_None
# 54            486,000.00  Closed Lost  Prod_Category_A_None
# 55            486,000.00  Closed Lost  Prod_Category_A_None
# 56            576,720.00  Closed Lost  Prod_Category_A_None
# 57            576,720.00  Closed Lost  Prod_Category_A_None
# 58            576,720.00  Closed Lost  Prod_Category_A_None
# 59            576,720.00  Closed Lost  Prod_Category_A_None
# 60            576,720.00  Closed Lost  Prod_Category_A_None
# 61            576,720.00  Closed Lost  Prod_Category_A_None
# 62            259,875.00  Closed Lost  Prod_Category_A_None
# 63            103,350.00   Closed Won  Prod_Category_A_None
# 64          3,184,974.00   Closed Won  Prod_Category_A_None
# 65            243,360.00   Closed Won  Prod_Category_A_None
# 66            214,500.00   Closed Won  Prod_Category_A_None
# 67            214,500.00   Closed Won  Prod_Category_A_None
# 68          1,556,587.50  Closed Lost  Prod_Category_A_None
# 69            549,780.00  Closed Lost  Prod_Category_A_None
# 70            420,750.00   Closed Won  Prod_Category_A_None
# 71            420,750.00   Closed Won  Prod_Category_A_None
# 72            420,750.00   Closed Won  Prod_Category_A_None
# 73            429,000.00   Closed Won  Prod_Category_A_None
# 74            429,000.00   Closed Won  Prod_Category_A_None
# 75            429,000.00   Closed Won  Prod_Category_A_None
# 76            429,000.00   Closed Won  Prod_Category_A_None
# 77              3,920.00   Closed Won  Prod_Category_A_None
# 78              7,695.00  Closed Lost  Prod_Category_A_None
# 79         19,874,400.00   Closed Won  Prod_Category_A_None
# 80         19,874,400.00   Closed Won  Prod_Category_A_None
# 81            510,510.00  Closed Lost  Prod_Category_A_None
# 82            105,300.00  Closed Lost  Prod_Category_A_None
# 83            364,905.00   Closed Won  Prod_Category_A_None
# 84          5,618,160.00  Closed Lost  Prod_Category_A_None
# 85            103,950.00   Closed Won  Prod_Category_A_None
# 86            103,950.00   Closed Won  Prod_Category_A_None
# 87            103,950.00   Closed Won  Prod_Category_A_None
# 88            599,880.00  Closed Lost  Prod_Category_A_None
# 89            599,880.00  Closed Lost  Prod_Category_A_None
# 90            599,880.00  Closed Lost  Prod_Category_A_None
# 91            599,880.00  Closed Lost  Prod_Category_A_None
# 92            599,880.00  Closed Lost  Prod_Category_A_None
# 93          1,154,600.00  Closed Lost  Prod_Category_A_None
# 94          1,154,600.00  Closed Lost  Prod_Category_A_None
# 95          1,154,600.00  Closed Lost  Prod_Category_A_None
# 96          1,154,600.00  Closed Lost  Prod_Category_A_None
# 97          1,154,600.00  Closed Lost  Prod_Category_A_None
# 98          1,154,600.00  Closed Lost  Prod_Category_A_None
# 99            571,800.00  Closed Lost  Prod_Category_A_None

# %% [markdown]
# # 1)Análisis del DataFrame

# %%
entrenamientoDf.info()
#Las columnas de ASP,ASP_(converted) y Total_Amount tienen elementos nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  16947 non-null  int64
#  1   Region                              16947 non-null  object
#  2   Territory                           16947 non-null  object
#  3   Pricing, Delivery_Terms_Quote_Appr  16947 non-null  int64
#  4   Pricing, Delivery_Terms_Approved    16947 non-null  int64
#  5   Bureaucratic_Code_0_Approval        16947 non-null  int64
#  6   Bureaucratic_Code_0_Approved        16947 non-null  int64
#  7   Submitted_for_Approval              16947 non-null  int64
#  8   Bureaucratic_Code                   16947 non-null  object
#  9   Account_Created_Date                16947 non-null  object
#  10  Source                              16947 non-null  object
#  11  Billing_Country                     16947 non-null  object
#  12  Account_Name                        16947 non-null  object
#  13  Opportunity_Name                    16947 non-null  object
#  14  Opportunity_ID                      16947 non-null  int64
#  15  Sales_Contract_No                   16947 non-null  object
#  16  Account_Owner                       16947 non-null  object
#  17  Opportunity_Owner                   16947 non-null  object
#  18  Account_Type                        16947 non-null  object
#  19  Opportunity_Type                    16947 non-null  object
#  20  Quote_Type                          16947 non-null  object
#  21  Delivery_Terms                      16947 non-null  object
#  22  Opportunity_Created_Date            16947 non-null  object
#  23  Brand                               16947 non-null  object
#  24  Product_Type                        16947 non-null  object
#  25  Size                                16947 non-null  object
#  26  Product_Category_B                  16947 non-null  object
#  27  Price                               16947 non-null  object
#  28  Currency                            16947 non-null  object
#  29  Last_Activity                       16947 non-null  object
#  30  Quote_Expiry_Date                   16947 non-null  object
#  31  Last_Modified_Date                  16947 non-null  object
#  32  Last_Modified_By                    16947 non-null  object
#  33  Product_Family                      16947 non-null  object
#  34  Product_Name                        16947 non-null  object
#  35  ASP_Currency                        16947 non-null  object
#  36  ASP                                 13738 non-null  float64
#  37  ASP_(converted)_Currency            16947 non-null  object
#  38  ASP_(converted)                     13738 non-null  float64
#  39  Planned_Delivery_Start_Date         16947 non-null  object
#  40  Planned_Delivery_End_Date           16947 non-null  object
#  41  Month                               16947 non-null  object
#  42  Delivery_Quarter                    16947 non-null  object
#  43  Delivery_Year                       16947 non-null  int64
#  44  Actual_Delivery_Date                16947 non-null  object
#  45  TRF                                 16947 non-null  int64
#  46  Total_Amount_Currency               16947 non-null  object
#  47  Total_Amount                        16888 non-null  float64
#  48  Total_Taxable_Amount_Currency       16947 non-null  object
#  49  Total_Taxable_Amount                16947 non-null  float64
#  50  Stage                               16947 non-null  object
#  51  Prod_Category_A                     16947 non-null  object
# dtypes: float64(4), int64(9), object(39)
# memory usage: 6.7+ MB

# %% [markdown]
# Aqui podemos ver que las columnas:
#
# 1.   ASP
# 2.   ASP_converted
# 3.   Total_Amount

# %%
entrenamientoDf['Last_Activity'].value_counts()
# Out:
# NaT    16947
# Name: Last_Activity, dtype: int64

# %%
entrenamientoDf['ASP_(converted)_Currency'].value_counts()
# Out:
# USD    16947
# Name: ASP_(converted)_Currency, dtype: int64

# %%
entrenamientoDf.groupby(['Product_Name','ASP','TRF']).count()
# Out:
#                             ID  Region  Territory  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0     9       9          9
# Product_Name_1    0.00 0     2       2          2
# Product_Name_10   0.00 0     7       7          7
# Product_Name_100  0.00 0    16      16         16
#                   0.15 0     1       1          1
# ...                         ..     ...        ...
# Product_Name_99   0.65 5     1       1          1
#                   0.67 5     1       1          1
#                   1.70 5     1       1          1
#                  68.00 3     1       1          1
#                  78.00 10    1       1          1
#
#                             Pricing, Delivery_Terms_Quote_Appr  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                                     9
# Product_Name_1    0.00 0                                     2
# Product_Name_10   0.00 0                                     7
# Product_Name_100  0.00 0                                    16
#                   0.15 0                                     1
# ...                                                        ...
# Product_Name_99   0.65 5                                     1
#                   0.67 5                                     1
#                   1.70 5                                     1
#                  68.00 3                                     1
#                  78.00 10                                    1
#
#                             Pricing, Delivery_Terms_Approved  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                                   9
# Product_Name_1    0.00 0                                   2
# Product_Name_10   0.00 0                                   7
# Product_Name_100  0.00 0                                  16
#                   0.15 0                                   1
# ...                                                      ...
# Product_Name_99   0.65 5                                   1
#                   0.67 5                                   1
#                   1.70 5                                   1
#                  68.00 3                                   1
#                  78.00 10                                  1
#
#                             Bureaucratic_Code_0_Approval  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                               9
# Product_Name_1    0.00 0                               2
# Product_Name_10   0.00 0                               7
# Product_Name_100  0.00 0                              16
#                   0.15 0                               1
# ...                                                  ...
# Product_Name_99   0.65 5                               1
#                   0.67 5                               1
#                   1.70 5                               1
#                  68.00 3                               1
#                  78.00 10                              1
#
#                             Bureaucratic_Code_0_Approved  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                               9
# Product_Name_1    0.00 0                               2
# Product_Name_10   0.00 0                               7
# Product_Name_100  0.00 0                              16
#                   0.15 0                               1
# ...                                                  ...
# Product_Name_99   0.65 5                               1
#                   0.67 5                               1
#                   1.70 5                               1
#                  68.00 3                               1
#                  78.00 10                              1
#
#                             Submitted_for_Approval  Bureaucratic_Code  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                         9                  9
# Product_Name_1    0.00 0                         2                  2
# Product_Name_10   0.00 0                         7                  7
# Product_Name_100  0.00 0                        16                 16
#                   0.15 0                         1                  1
# ...                                            ...                ...
# Product_Name_99   0.65 5                         1                  1
#                   0.67 5                         1                  1
#                   1.70 5                         1                  1
#                  68.00 3                         1                  1
#                  78.00 10                        1                  1
#
#                             Account_Created_Date  Source   Billing_Country  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                       9        9                9
# Product_Name_1    0.00 0                       2        2                2
# Product_Name_10   0.00 0                       7        7                7
# Product_Name_100  0.00 0                      16       16               16
#                   0.15 0                       1        1                1
# ...                                          ...      ...              ...
# Product_Name_99   0.65 5                       1        1                1
#                   0.67 5                       1        1                1
#                   1.70 5                       1        1                1
#                  68.00 3                       1        1                1
#                  78.00 10                      1        1                1
#
#                             Account_Name  Opportunity_Name  Opportunity_ID  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0               9                 9               9
# Product_Name_1    0.00 0               2                 2               2
# Product_Name_10   0.00 0               7                 7               7
# Product_Name_100  0.00 0              16                16              16
#                   0.15 0               1                 1               1
# ...                                  ...               ...             ...
# Product_Name_99   0.65 5               1                 1               1
#                   0.67 5               1                 1               1
#                   1.70 5               1                 1               1
#                  68.00 3               1                 1               1
#                  78.00 10              1                 1               1
#
#                             Sales_Contract_No  Account_Owner  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                    9              9
# Product_Name_1    0.00 0                    2              2
# Product_Name_10   0.00 0                    7              7
# Product_Name_100  0.00 0                   16             16
#                   0.15 0                    1              1
# ...                                       ...            ...
# Product_Name_99   0.65 5                    1              1
#                   0.67 5                    1              1
#                   1.70 5                    1              1
#                  68.00 3                    1              1
#                  78.00 10                   1              1
#
#                             Opportunity_Owner  Account_Type  Opportunity_Type  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                    9             9                 9
# Product_Name_1    0.00 0                    2             2                 2
# Product_Name_10   0.00 0                    7             7                 7
# Product_Name_100  0.00 0                   16            16                16
#                   0.15 0                    1             1                 1
# ...                                       ...           ...               ...
# Product_Name_99   0.65 5                    1             1                 1
#                   0.67 5                    1             1                 1
#                   1.70 5                    1             1                 1
#                  68.00 3                    1             1                 1
#                  78.00 10                   1             1                 1
#
#                             Quote_Type  Delivery_Terms  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0             9               9
# Product_Name_1    0.00 0             2               2
# Product_Name_10   0.00 0             7               7
# Product_Name_100  0.00 0            16              16
#                   0.15 0             1               1
# ...                                ...             ...
# Product_Name_99   0.65 5             1               1
#                   0.67 5             1               1
#                   1.70 5             1               1
#                  68.00 3             1               1
#                  78.00 10            1               1
#
#                             Opportunity_Created_Date  Brand  Product_Type  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                           9      9             9
# Product_Name_1    0.00 0                           2      2             2
# Product_Name_10   0.00 0                           7      7             7
# Product_Name_100  0.00 0                          16     16            16
#                   0.15 0                           1      1             1
# ...                                              ...    ...           ...
# Product_Name_99   0.65 5                           1      1             1
#                   0.67 5                           1      1             1
#                   1.70 5                           1      1             1
#                  68.00 3                           1      1             1
#                  78.00 10                          1      1             1
#
#                             Size  Product_Category_B  Price  Currency  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0       9                   9      9         9
# Product_Name_1    0.00 0       2                   2      2         2
# Product_Name_10   0.00 0       7                   7      7         7
# Product_Name_100  0.00 0      16                  16     16        16
#                   0.15 0       1                   1      1         1
# ...                          ...                 ...    ...       ...
# Product_Name_99   0.65 5       1                   1      1         1
#                   0.67 5       1                   1      1         1
#                   1.70 5       1                   1      1         1
#                  68.00 3       1                   1      1         1
#                  78.00 10      1                   1      1         1
#
#                             Last_Activity  Quote_Expiry_Date  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                9                  9
# Product_Name_1    0.00 0                2                  2
# Product_Name_10   0.00 0                7                  7
# Product_Name_100  0.00 0               16                 16
#                   0.15 0                1                  1
# ...                                   ...                ...
# Product_Name_99   0.65 5                1                  1
#                   0.67 5                1                  1
#                   1.70 5                1                  1
#                  68.00 3                1                  1
#                  78.00 10               1                  1
#
#                             Last_Modified_Date  Last_Modified_By  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                     9                 9
# Product_Name_1    0.00 0                     2                 2
# Product_Name_10   0.00 0                     7                 7
# Product_Name_100  0.00 0                    16                16
#                   0.15 0                     1                 1
# ...                                        ...               ...
# Product_Name_99   0.65 5                     1                 1
#                   0.67 5                     1                 1
#                   1.70 5                     1                 1
#                  68.00 3                     1                 1
#                  78.00 10                    1                 1
#
#                             Product_Family  ASP_Currency  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                 9             9
# Product_Name_1    0.00 0                 2             2
# Product_Name_10   0.00 0                 7             7
# Product_Name_100  0.00 0                16            16
#                   0.15 0                 1             1
# ...                                    ...           ...
# Product_Name_99   0.65 5                 1             1
#                   0.67 5                 1             1
#                   1.70 5                 1             1
#                  68.00 3                 1             1
#                  78.00 10                1             1
#
#                             ASP_(converted)_Currency  ASP_(converted)  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                           9                9
# Product_Name_1    0.00 0                           2                2
# Product_Name_10   0.00 0                           7                7
# Product_Name_100  0.00 0                          16               16
#                   0.15 0                           1                1
# ...                                              ...              ...
# Product_Name_99   0.65 5                           1                1
#                   0.67 5                           1                1
#                   1.70 5                           1                1
#                  68.00 3                           1                1
#                  78.00 10                          1                1
#
#                             Planned_Delivery_Start_Date  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                              9
# Product_Name_1    0.00 0                              2
# Product_Name_10   0.00 0                              7
# Product_Name_100  0.00 0                             16
#                   0.15 0                              1
# ...                                                 ...
# Product_Name_99   0.65 5                              1
#                   0.67 5                              1
#                   1.70 5                              1
#                  68.00 3                              1
#                  78.00 10                             1
#
#                             Planned_Delivery_End_Date  Month  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                            9      9
# Product_Name_1    0.00 0                            2      2
# Product_Name_10   0.00 0                            7      7
# Product_Name_100  0.00 0                           16     16
#                   0.15 0                            1      1
# ...                                               ...    ...
# Product_Name_99   0.65 5                            1      1
#                   0.67 5                            1      1
#                   1.70 5                            1      1
#                  68.00 3                            1      1
#                  78.00 10                           1      1
#
#                             Delivery_Quarter  Delivery_Year  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                   9              9
# Product_Name_1    0.00 0                   2              2
# Product_Name_10   0.00 0                   7              7
# Product_Name_100  0.00 0                  16             16
#                   0.15 0                   1              1
# ...                                      ...            ...
# Product_Name_99   0.65 5                   1              1
#                   0.67 5                   1              1
#                   1.70 5                   1              1
#                  68.00 3                   1              1
#                  78.00 10                  1              1
#
#                             Actual_Delivery_Date  Total_Amount_Currency  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                       9                      9
# Product_Name_1    0.00 0                       2                      2
# Product_Name_10   0.00 0                       7                      7
# Product_Name_100  0.00 0                      16                     16
#                   0.15 0                       1                      1
# ...                                          ...                    ...
# Product_Name_99   0.65 5                       1                      1
#                   0.67 5                       1                      1
#                   1.70 5                       1                      1
#                  68.00 3                       1                      1
#                  78.00 10                      1                      1
#
#                             Total_Amount  Total_Taxable_Amount_Currency  \
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0               9                              9
# Product_Name_1    0.00 0               2                              2
# Product_Name_10   0.00 0               7                              7
# Product_Name_100  0.00 0              16                             16
#                   0.15 0               1                              1
# ...                                  ...                            ...
# Product_Name_99   0.65 5               1                              1
#                   0.67 5               1                              1
#                   1.70 5               0                              1
#                  68.00 3               1                              1
#                  78.00 10              0                              1
#
#                             Total_Taxable_Amount  Stage  Prod_Category_A
# Product_Name     ASP   TRF
# Product_Name_0    0.00 0                       9      9                9
# Product_Name_1    0.00 0                       2      2                2
# Product_Name_10   0.00 0                       7      7                7
# Product_Name_100  0.00 0                      16     16               16
#                   0.15 0                       1      1                1
# ...                                          ...    ...              ...
# Product_Name_99   0.65 5                       1      1                1
#                   0.67 5                       1      1                1
#                   1.70 5                       1      1                1
#                  68.00 3                       1      1                1
#                  78.00 10                      1      1                1
#
# [5003 rows x 49 columns]

# %%
entrenamientoDf['Actual_Delivery_Date'].value_counts()
# Out:
# NaT    16947
# Name: Actual_Delivery_Date, dtype: int64

# %%
entrenamientoDf['Product_Name'].value_counts()
# Out:
# Product_Name_100    976
# Product_Name_226    836
# Product_Name_231    579
# Product_Name_491    524
# Product_Name_4      474
#                    ...
# Product_Name_183      1
# Product_Name_73       1
# Product_Name_156      1
# Product_Name_506      1
# Product_Name_313      1
# Name: Product_Name, Length: 456, dtype: int64

# %%
entrenamientoDf[(entrenamientoDf['ASP_Currency']=='JPY')]['ASP'].value_counts()
# Out:
#  0.00    228
# 55.00    156
# 65.00    153
# 68.00    139
# 50.00    121
# 53.00    109
# 75.00     99
# 78.00     86
# 45.00     74
# 48.00     62
# 46.00     57
# 59.00     38
# 51.00     38
# 40.00     33
# 57.00     32
# 66.00     27
# 56.00     25
# 49.00     22
# 54.00     20
# 72.00     20
# 67.00     16
# 44.00     16
# 42.00     16
# 71.00     15
# 80.00     14
# 52.00     12
# 60.00     12
# 62.00     12
# 77.00     12
# 43.00     11
# 70.00     11
# 38.00     10
# 74.00     10
# 73.00     10
# 69.00     10
# 47.00      9
# 58.00      8
# 37.00      7
# 39.00      6
# 41.00      6
# 76.00      6
# 36.00      5
# 63.00      4
# 61.00      3
# 64.00      2
# 35.00      1
# 34.00      1
# 30.00      1
# 33.00      1
# Name: ASP, dtype: int64

# %%
entrenamientoDf['Price'].value_counts()
# Out:
# None     15982
# Other      609
# 0.24        27
# 0.41        22
# 0.28        20
# 0.27        18
# 0.29        17
# 0.32        15
# 0.35        14
# 0.38        14
# 0.23        13
# 0.33        12
# 0.42        12
# 0.34        11
# 0.26        11
# 0.3         11
# 0.31        10
# 0.245        8
# 0.25         7
# 0.305        7
# 0.22         6
# 0.39         6
# 0.335        6
# 0.47         6
# 0.325        6
# 0.45         6
# 0.225        6
# 0.2          5
# 0.36         4
# 0.37         4
# 0.285        4
# 0.445        4
# 0.275        4
# 0.265        3
# 0.295        3
# 0.355        3
# 0.255        3
# 0.215        2
# 0.49         2
# 0.345        2
# 0.505        2
# 0.56         2
# 0.315        2
# 0.48         2
# 0.375        2
# 0.4          2
# 0.235        2
# 0.44         2
# 0.52         2
# 0.21         1
# 0.365        1
# 0.55         1
# 0.465        1
# Name: Price, dtype: int64

# %%
entrenamientoDf['Stage']=='Closed_Won'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16942    False
# 16943    False
# 16944    False
# 16945    False
# 16946    False
# Name: Stage, Length: 16947, dtype: bool

# %%
entrenamientoDf.groupby(['Region','Stage']).agg({'ASP':'mean','ASP_(converted)':'mean'}).head()
# Out:
#                                         ASP      ASP_(converted)
# Region   Stage
# APAC     Closed Lost                   0.41                 0.39
#          Closed Won                    0.39                 0.35
#          Proposal                      0.32                 0.32
#          Qualification                 0.30                 0.30
# Americas Closed Lost                   0.46                 0.46

# %% [markdown]
# # A) Análisis columna Total Taxable Amount

# %% [markdown]
# Hipótesis: La columna Total_Taxable_Amount es el total de la suma del Total_Amount de cada uno de los items de una oportunidad.

# %%
grouped_by_oportunity_name = entrenamientoDf.groupby(['Opportunity_Name']).agg({'ASP':'count','Total_Amount':'sum','Total_Taxable_Amount': 'max'})

# %%
grouped_by_oportunity_name = grouped_by_oportunity_name.rename(columns={'ASP':'items_per_oport','Total_Amount':'Total_Amount_Sum'})

# %%
grouped_by_oportunity_name.reset_index()
# Out:
#             Opportunity_Name  items_per_oport     Total_Amount_Sum  \
# 0         Opportunity_Name_0                7         3,494,400.00
# 1         Opportunity_Name_1                7         2,193,100.00
# 2       Opportunity_Name_100                1           543,780.00
# 3      Opportunity_Name_1000                1       142,142,000.00
# 4     Opportunity_Name_10000                1            19,600.00
# ...                      ...              ...                  ...
# 9836   Opportunity_Name_9992                1           175,190.40
# 9837   Opportunity_Name_9995                1         1,043,490.00
# 9838   Opportunity_Name_9996                1           790,246.88
# 9839   Opportunity_Name_9997                1         3,799,810.00
# 9840   Opportunity_Name_9998                1           362,610.00
#
#       Total_Taxable_Amount
# 0             3,494,400.00
# 1             2,193,100.00
# 2               543,780.00
# 3           142,142,000.00
# 4                     0.00
# ...                    ...
# 9836                  0.00
# 9837          1,043,490.00
# 9838            790,246.88
# 9839          3,799,810.00
# 9840            362,610.00
#
# [9841 rows x 4 columns]

# %% [markdown]
# Conclusión: Podemos ver que la columna Total Taxable Amount coincide con la suma del Amount de cada uno de los items de una misma oportunidad de venta.

# %%
grouped_by_oportunity_name = grouped_by_oportunity_name.merge(entrenamientoDf[['Stage','Opportunity_Name']],on='Opportunity_Name')

# %%
grouped_by_oportunity_name = grouped_by_oportunity_name.drop_duplicates(subset='Opportunity_Name')

# %%
#otra forma de obtener lo mismo de arriba.
grouped_by_oportunity_name.merge(entrenamientoDf.Opportunity_Name.drop_duplicates(),on='Opportunity_Name',how="right").nlargest(10,'Total_Amount_Sum')
# Out:
#            Opportunity_Name  items_per_oport     Total_Amount_Sum  \
# 9386  Opportunity_Name_5000                1     1,320,000,000.00
# 3054  Opportunity_Name_5778                1       919,992,410.00
# 9107   Opportunity_Name_496                1       760,000,000.00
# 3053  Opportunity_Name_4881                1       660,005,280.00
# 9202  Opportunity_Name_4879                1       660,004,620.00
# 3048  Opportunity_Name_5860                1       523,138,680.00
# 8977  Opportunity_Name_6236                1       400,000,000.00
# 9404  Opportunity_Name_4974                1       389,880,000.00
# 9709  Opportunity_Name_6879                1       315,000,081.90
# 9673  Opportunity_Name_3875                1       256,201,545.60
#
#       Total_Taxable_Amount          Stage
# 9386         11,867,301.99       Proposal
# 3054        919,992,410.00    Closed Lost
# 9107        760,000,000.00       Proposal
# 3053        660,005,280.00    Closed Lost
# 9202        660,004,620.00  Qualification
# 3048        523,138,680.00    Closed Lost
# 8977        400,000,000.00    Closed Lost
# 9404        389,880,000.00       Proposal
# 9709        315,000,081.90    Closed Lost
# 9673        256,201,545.60    Closed Lost

# %%
grouped_by_oportunity_name.nlargest(10, 'Total_Taxable_Amount')
# Out:
#             Opportunity_Name  items_per_oport     Total_Amount_Sum  \
# 12105  Opportunity_Name_6550                1        12,194,000.00
# 10741  Opportunity_Name_5778                1       919,992,410.00
# 9540    Opportunity_Name_496                1       760,000,000.00
# 9413   Opportunity_Name_4881                1       660,005,280.00
# 9404   Opportunity_Name_4879                1       660,004,620.00
# 10844  Opportunity_Name_5860                1       523,138,680.00
# 11744  Opportunity_Name_6236                1       400,000,000.00
# 9546   Opportunity_Name_4974                1       389,880,000.00
# 12726  Opportunity_Name_6879                1       315,000,081.90
# 7989   Opportunity_Name_3875                1       256,201,545.60
#
#        Total_Taxable_Amount          Stage
# 12105      1,356,338,620.00     Closed Won
# 10741        919,992,410.00    Closed Lost
# 9540         760,000,000.00       Proposal
# 9413         660,005,280.00    Closed Lost
# 9404         660,004,620.00  Qualification
# 10844        523,138,680.00    Closed Lost
# 11744        400,000,000.00    Closed Lost
# 9546         389,880,000.00       Proposal
# 12726        315,000,081.90    Closed Lost
# 7989         256,201,545.60    Closed Lost

# %% [markdown]
# # B) Analizamos performance de los vendedores.

# %%
# Primero filtro y me quedo con las ventas realizadas

df_closed_won = entrenamientoDf[entrenamientoDf['Stage']=='Closed Won']

# %%
df_closed_won['Total_Taxable_Amount_USD'] = (df_closed_won['ASP_(converted)'] / df_closed_won['ASP']) * (df_closed_won['Total_Taxable_Amount'])
# Out:
# /home/fernando/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_closed_won.nlargest(5, 'Total_Taxable_Amount_USD')
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 2200   27692     Japan        None                                   1
# 16135  20265  Americas  NW America                                   1
# 16136  20268  Americas  NW America                                   1
# 16137  20271  Americas  NW America                                   1
# 16138  20274  Americas  NW America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 2200                                  1                             1
# 16135                                 0                             1
# 16136                                 0                             1
# 16137                                 0                             1
# 16138                                 0                             1
#
#        Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# 2200                              1                       0
# 16135                             0                       0
# 16136                             0                       0
# 16137                             0                       0
# 16138                             0                       0
#
#          Bureaucratic_Code Account_Created_Date   Source  Billing_Country  \
# 2200   Bureaucratic_Code_4            6/11/2015  Source_3           Japan
# 16135  Bureaucratic_Code_5            8/22/2013      None   United States
# 16136  Bureaucratic_Code_5            8/22/2013      None   United States
# 16137  Bureaucratic_Code_5            8/22/2013      None   United States
# 16138  Bureaucratic_Code_5            8/22/2013      None   United States
#
#             Account_Name       Opportunity_Name  Opportunity_ID  \
# 2200   Account_Name_1074  Opportunity_Name_6550            1248
# 16135  Account_Name_1409   Opportunity_Name_844           12390
# 16136  Account_Name_1409   Opportunity_Name_844           12390
# 16137  Account_Name_1409   Opportunity_Name_844           12390
# 16138  Account_Name_1409   Opportunity_Name_844           12390
#
#       Sales_Contract_No   Account_Owner Opportunity_Owner    Account_Type  \
# 2200                116  Person_Name_61    Person_Name_66  Account_Type_0
# 16135              None   Person_Name_8     Person_Name_8  Account_Type_2
# 16136              None   Person_Name_8     Person_Name_8  Account_Type_2
# 16137              None   Person_Name_8     Person_Name_8  Account_Type_2
# 16138              None   Person_Name_8     Person_Name_8  Account_Type_2
#
#           Opportunity_Type   Quote_Type    Delivery_Terms  \
# 2200    Opportunity_Type_1  Non Binding  Delivery_Terms_5
# 16135  Opportunity_Type_19      Binding  Delivery_Terms_4
# 16136  Opportunity_Type_19      Binding  Delivery_Terms_4
# 16137  Opportunity_Type_19      Binding  Delivery_Terms_4
# 16138  Opportunity_Type_19      Binding  Delivery_Terms_4
#
#       Opportunity_Created_Date Brand Product_Type  Size Product_Category_B  \
# 2200                 2/19/2016  None         None  None               None
# 16135                12/8/2014  None         None  None               None
# 16136                12/8/2014  None         None  None               None
# 16137                12/8/2014  None         None  None               None
# 16138                12/8/2014  None         None  None               None
#
#       Price Currency Last_Activity Quote_Expiry_Date Last_Modified_Date  \
# 2200   None     None           NaT         3/23/2016          12/4/2016
# 16135  None     None           NaT         4/30/2015          8/25/2015
# 16136  None     None           NaT         4/30/2015          8/25/2015
# 16137  None     None           NaT         4/30/2015          8/25/2015
# 16138  None     None           NaT         4/30/2015          8/25/2015
#
#       Last_Modified_By      Product_Family      Product_Name ASP_Currency  \
# 2200    Person_Name_47   Product_Family_77  Product_Name_100          USD
# 16135   Person_Name_33  Product_Family_164  Product_Name_308          USD
# 16136   Person_Name_33  Product_Family_158  Product_Name_285          USD
# 16137   Person_Name_33  Product_Family_164  Product_Name_307          USD
# 16138   Person_Name_33  Product_Family_158  Product_Name_286          USD
#
#                        ASP ASP_(converted)_Currency      ASP_(converted)  \
# 2200                 67.00                      USD                67.00
# 16135                 0.69                      USD                 0.69
# 16136                 0.69                      USD                 0.69
# 16137                 0.69                      USD                 0.69
# 16138                 0.69                      USD                 0.69
#
#       Planned_Delivery_Start_Date Planned_Delivery_End_Date     Month  \
# 2200                     3/1/2016                 3/11/2016  2016 - 3
# 16135                    4/1/2016                 4/30/2016  2016 - 4
# 16136                    4/1/2016                 4/30/2016  2016 - 4
# 16137                    3/1/2016                 3/31/2016  2016 - 3
# 16138                    3/1/2016                 3/31/2016  2016 - 3
#
#       Delivery_Quarter  Delivery_Year Actual_Delivery_Date  TRF  \
# 2200                Q1           2016                  NaT    0
# 16135               Q2           2016                  NaT    6
# 16136               Q2           2016                  NaT    2
# 16137               Q1           2016                  NaT   21
# 16138               Q1           2016                  NaT   15
#
#       Total_Amount_Currency         Total_Amount  \
# 2200                    USD        12,194,000.00
# 16135                   USD         3,992,215.34
# 16136                   USD         1,289,309.84
# 16137                   USD        14,410,505.18
# 16138                   USD        10,597,690.85
#
#       Total_Taxable_Amount_Currency  Total_Taxable_Amount       Stage  \
# 2200                            JPY      1,356,338,620.00  Closed Won
# 16135                           USD        177,627,662.70  Closed Won
# 16136                           USD        177,627,662.70  Closed Won
# 16137                           USD        177,627,662.70  Closed Won
# 16138                           USD        177,627,662.70  Closed Won
#
#             Prod_Category_A  Total_Taxable_Amount_USD
# 2200   Prod_Category_A_None          1,356,338,620.00
# 16135  Prod_Category_A_None            177,627,662.70
# 16136  Prod_Category_A_None            177,627,662.70
# 16137  Prod_Category_A_None            177,627,662.70
# 16138  Prod_Category_A_None            177,627,662.70

# %% [markdown]
# Agrupo por vendedor

# %%
total_sells_per_seller = df_closed_won.groupby('Opportunity_Owner').agg({'Total_Taxable_Amount_USD':'sum'})

# %%
# Los mejores 5 vendedores en base a la cantidad de dinero ingresado en la empresa por sus ventas

total_sells_per_seller.nlargest(5, 'Total_Taxable_Amount_USD')
# Out:
#                    Total_Taxable_Amount_USD
# Opportunity_Owner
# Person_Name_8              4,050,474,355.81
# Person_Name_66             1,424,166,814.18
# Person_Name_13               655,147,097.41
# Person_Name_4                320,394,540.09
# Person_Name_12               210,630,603.30

# %% [markdown]
# Analizamos el porcentaje de oportunidades cerradas exitosamente por cada vendedor.

# %%
df_sellers = entrenamientoDf[['Stage','Opportunity_Owner','Opportunity_Name']]

# %%
# Cada oportunidad puede tener asociadas varios registros. Nos quedamos unicamente con un registro por oportunidad.
# Tomamos como hipótesis que una oportunidad tiene asociada un único vendedor

df_sellers = df_sellers.drop_duplicates(subset='Opportunity_Name')

# %%
# Calculamos el promedio de cada Stage para cada vendedor

stages = df_sellers.groupby('Opportunity_Owner')["Stage"]
stages = stages.value_counts() / stages.count()
stages = stages.to_frame().unstack().fillna(0)
stages.columns = ['prom_lost','prom_won','prom_proposal','prom_qualification','prom_negotiation']
stages.nlargest(5,'prom_won')
# Out:
#                              prom_lost             prom_won  \
# Opportunity_Owner
# Person_Name_30                    0.00                 1.00
# Person_Name_19                    0.03                 0.97
# Person_Name_40                    0.12                 0.88
# Person_Name_52                    0.22                 0.78
# Person_Name_32                    0.23                 0.77
#
#                          prom_proposal   prom_qualification  \
# Opportunity_Owner
# Person_Name_30                    0.00                 0.00
# Person_Name_19                    0.00                 0.00
# Person_Name_40                    0.00                 0.00
# Person_Name_52                    0.00                 0.00
# Person_Name_32                    0.00                 0.00
#
#                       prom_negotiation
# Opportunity_Owner
# Person_Name_30                    0.00
# Person_Name_19                    0.00
# Person_Name_40                    0.00
# Person_Name_52                    0.00
# Person_Name_32                    0.00

# %% [markdown]
# Podemos ver que estos resultados pueden no estar siendo representativos debido al problema relacionado con *La ecuación más peligrosa de la historia*.
#
# Para solucionarlo, filtramos el data frame y nos quedamos únicamente con los vendedores que tengan más de x oportunidades asociadas, dónde x vamos a tomarlo como el promedio de oportunidades por vendedor.

# %%
promedio_opor_vendedor = df_sellers.groupby('Opportunity_Owner')['Stage'].count().mean()
promedio_opor_vendedor
# Out:
# 185.67924528301887

# %%
# Repetimos mismos cálculos de antes, pero quedandonos únicamente con los vendedores
# que tengan asociados más de 185 oportunidades.

df_sellers['cant_oport'] = df_sellers.groupby('Opportunity_Owner')['Stage'].transform('count')

# %%
df_sellers
# Out:
#              Stage Opportunity_Owner        Opportunity_Name  cant_oport
# 0      Closed Lost    Person_Name_18  Opportunity_Name_12598         682
# 1       Closed Won    Person_Name_20  Opportunity_Name_12600          42
# 2       Closed Won     Person_Name_8    Opportunity_Name_469         763
# 3      Closed Lost     Person_Name_8    Opportunity_Name_415         763
# 4      Closed Lost     Person_Name_8    Opportunity_Name_851         763
# ...            ...               ...                     ...         ...
# 16939   Closed Won    Person_Name_13   Opportunity_Name_7202         757
# 16940  Closed Lost    Person_Name_13  Opportunity_Name_11979         757
# 16942   Closed Won    Person_Name_13   Opportunity_Name_9245         757
# 16945  Closed Lost     Person_Name_3   Opportunity_Name_5843         578
# 16946  Closed Lost     Person_Name_3   Opportunity_Name_9911         578
#
# [9841 rows x 4 columns]

# %%
df_sellers_filtrado = df_sellers.loc[df_sellers['cant_oport'] >= promedio_opor_vendedor]

# %%
df_sellers_filtrado
# Out:
#              Stage Opportunity_Owner        Opportunity_Name  cant_oport
# 0      Closed Lost    Person_Name_18  Opportunity_Name_12598         682
# 2       Closed Won     Person_Name_8    Opportunity_Name_469         763
# 3      Closed Lost     Person_Name_8    Opportunity_Name_415         763
# 4      Closed Lost     Person_Name_8    Opportunity_Name_851         763
# 5      Closed Lost     Person_Name_8    Opportunity_Name_939         763
# ...            ...               ...                     ...         ...
# 16939   Closed Won    Person_Name_13   Opportunity_Name_7202         757
# 16940  Closed Lost    Person_Name_13  Opportunity_Name_11979         757
# 16942   Closed Won    Person_Name_13   Opportunity_Name_9245         757
# 16945  Closed Lost     Person_Name_3   Opportunity_Name_5843         578
# 16946  Closed Lost     Person_Name_3   Opportunity_Name_9911         578
#
# [7348 rows x 4 columns]

# %%
stages = df_sellers_filtrado.groupby('Opportunity_Owner')["Stage"]
stages = stages.value_counts() / stages.count()
stages = stages.to_frame().unstack().fillna(0)
stages.columns = ['prom_lost','prom_won','prom_proposal','prom_qualification','prom_negotiation']
stages.nlargest(5,'prom_won')
# Out:
#                              prom_lost             prom_won  \
# Opportunity_Owner
# Person_Name_19                    0.03                 0.97
# Person_Name_32                    0.23                 0.77
# Person_Name_64                    0.31                 0.67
# Person_Name_66                    0.33                 0.65
# Person_Name_50                    0.37                 0.62
#
#                          prom_proposal   prom_qualification  \
# Opportunity_Owner
# Person_Name_19                    0.00                 0.00
# Person_Name_32                    0.00                 0.00
# Person_Name_64                    0.01                 0.00
# Person_Name_66                    0.00                 0.02
# Person_Name_50                    0.00                 0.00
#
#                       prom_negotiation
# Opportunity_Owner
# Person_Name_19                    0.00
# Person_Name_32                    0.00
# Person_Name_64                    0.00
# Person_Name_66                    0.00
# Person_Name_50                    0.01

# %% [markdown]
# Conclusión: Podemos ver que el resultado cambio, pero consideramos a estos últimos más representativos ya que no estamos teniendo en cuenta a los vendedores con pocos registros asociados.

# %% [markdown]
# # C) Analizamos regiones más calientes en cuanto a ingresos monetarios.

# %% [markdown]
# Chequeamos que todos los registros con Stage Closed_Won tengan un Average Selling Price

# %%
dfAux = df_closed_won['ASP']=='nan'
dfAux.value_counts()
# Out:
# /home/fernando/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# False    9533
# Name: ASP, dtype: int64

# %% [markdown]
# Convertimos la columna de Total_Taxable_Amount a una misma moneda, en este caso el dólar.

# %% [markdown]
# **Analizar casos especiales en los que no podemos realizar la conversión de JPY a USD**

# %%
dfAux = df_closed_won[(df_closed_won['Total_Taxable_Amount_Currency']=='JPY') & (df_closed_won['ASP_Currency']=='USD')]
dfAux
# Out:
#          ID Region Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 2200  27692  Japan      None                                   1
# 4805  21902  Japan      None                                   1
#
#       Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 2200                                 1                             1
# 4805                                 1                             1
#
#       Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# 2200                             1                       0
# 4805                             1                       0
#
#         Bureaucratic_Code Account_Created_Date    Source  Billing_Country  \
# 2200  Bureaucratic_Code_4            6/11/2015   Source_3           Japan
# 4805  Bureaucratic_Code_4            9/23/2013  Source_13           Japan
#
#            Account_Name       Opportunity_Name  Opportunity_ID  \
# 2200  Account_Name_1074  Opportunity_Name_6550            1248
# 4805  Account_Name_1991  Opportunity_Name_7751            2849
#
#      Sales_Contract_No   Account_Owner Opportunity_Owner    Account_Type  \
# 2200               116  Person_Name_61    Person_Name_66  Account_Type_0
# 4805               872  Person_Name_32    Person_Name_50  Account_Type_0
#
#         Opportunity_Type   Quote_Type    Delivery_Terms  \
# 2200  Opportunity_Type_1  Non Binding  Delivery_Terms_5
# 4805  Opportunity_Type_7  Non Binding  Delivery_Terms_4
#
#      Opportunity_Created_Date Brand Product_Type  Size Product_Category_B  \
# 2200                2/19/2016  None         None  None               None
# 4805               10/24/2016  None         None  None               None
#
#      Price Currency Last_Activity Quote_Expiry_Date Last_Modified_Date  \
# 2200  None     None           NaT         3/23/2016          12/4/2016
# 4805  None     None           NaT        10/24/2016          12/4/2016
#
#      Last_Modified_By     Product_Family      Product_Name ASP_Currency  \
# 2200   Person_Name_47  Product_Family_77  Product_Name_100          USD
# 4805   Person_Name_47  Product_Family_77  Product_Name_100          USD
#
#                       ASP ASP_(converted)_Currency      ASP_(converted)  \
# 2200                67.00                      USD                67.00
# 4805                 0.49                      USD                 0.49
#
#      Planned_Delivery_Start_Date Planned_Delivery_End_Date      Month  \
# 2200                    3/1/2016                 3/11/2016   2016 - 3
# 4805                  10/25/2016                10/25/2016  2016 - 10
#
#      Delivery_Quarter  Delivery_Year Actual_Delivery_Date  TRF  \
# 2200               Q1           2016                  NaT    0
# 4805               Q4           2016                  NaT    0
#
#      Total_Amount_Currency         Total_Amount Total_Taxable_Amount_Currency  \
# 2200                   USD        12,194,000.00                           JPY
# 4805                   USD             4,968.60                           JPY
#
#       Total_Taxable_Amount       Stage       Prod_Category_A  \
# 2200      1,356,338,620.00  Closed Won  Prod_Category_A_None
# 4805            552,657.00  Closed Won  Prod_Category_A_None
#
#       Total_Taxable_Amount_USD
# 2200          1,356,338,620.00
# 4805                552,657.00

# %% [markdown]
# Nos quedamos con las columnas que nos interesan para el análisis que queremos hacer.

# %%
closedWonShorted = df_closed_won[['Total_Taxable_Amount_USD','Region','Opportunity_Name']]

# %%
closedWonShorted.head(10)
# Out:
#     Total_Taxable_Amount_USD    Region        Opportunity_Name
# 1                  54,552.68      EMEA  Opportunity_Name_12600
# 2                  83,865.60  Americas    Opportunity_Name_469
# 7                  50,688.00  Americas   Opportunity_Name_8227
# 23              1,621,851.00      APAC   Opportunity_Name_7036
# 63                116,898.60      EMEA   Opportunity_Name_4062
# 64              3,184,974.00  Americas   Opportunity_Name_6397
# 65                  2,187.90     Japan   Opportunity_Name_5583
# 66                242,619.00      EMEA   Opportunity_Name_2804
# 67                242,619.00      EMEA   Opportunity_Name_2801
# 70                475,906.50      EMEA  Opportunity_Name_12137

# %% [markdown]
# Nos quedamos únicamente con un registro por oportunidad.

# %%
closedWonNoDuplicates = closedWonShorted.drop_duplicates(subset='Opportunity_Name')

# %%
closedWonNoDuplicates.head()
# Out:
#     Total_Taxable_Amount_USD    Region        Opportunity_Name
# 1                  54,552.68      EMEA  Opportunity_Name_12600
# 2                  83,865.60  Americas    Opportunity_Name_469
# 7                  50,688.00  Americas   Opportunity_Name_8227
# 23              1,621,851.00      APAC   Opportunity_Name_7036
# 63                116,898.60      EMEA   Opportunity_Name_4062

# %% [markdown]
# Agrupamos por región, y sumamos el monto a cobrar.

# %%
closedWonGroupedRegion = closedWonNoDuplicates.groupby('Region').agg({'Total_Taxable_Amount_USD':'sum'})
closedWonGroupedRegion = closedWonGroupedRegion.reset_index()
closedWonGroupedRegion
# Out:
#         Region  Total_Taxable_Amount_USD
# 0         APAC            200,207,326.37
# 1     Americas            748,257,485.60
# 2         EMEA            582,033,427.75
# 3        Japan          1,457,183,117.16
# 4  Middle East              4,750,701.94

# %%
closedWonPlot = sns.barplot(y=closedWonGroupedRegion.Region, x=closedWonGroupedRegion.Total_Taxable_Amount_USD, orient='h', color='r')
closedWonPlot.set_title("Titulo", fontsize=15)
closedWonPlot.set_ylabel("Region", fontsize=12)
closedWonPlot.set_xlabel("Total Taxable Amount (USD)", fontsize=12)
closedWonPlot.set_title("asd", fontsize=12)
# Out:
# Text(0.5, 1.0, 'asd')

# %% [markdown]
# # D) ANALISIS DE PORCENTAJE EXITO REGIONES

# %% [markdown]
# Una renglón representa un item de la oportunidad. Hay que eliminar los duplicados por oportunidad para no tomar en cuenta dos veces el estado de la misma oportunidad.

# %%
# Pregunta: Cual es la relacion entre la cantidad de casos con casos cerrados de manera exitosa por region ?
auxiliar_df = entrenamientoDf

#Eliminamos los Opportunity_Name duplicados para tener la cantidad neta de oportunidades
auxiliar_df = auxiliar_df.drop_duplicates(subset='Opportunity_Name')

# Nos guardamos en la columna Stage_Won los casos terminados en Closed Won

# ROMPE!!!! Comente tu linea y puse un posible arreglo,fijate si era lo que buscabas
#auxiliar_df["Stage_Won"] = auxiliar_df[auxiliar_df["Stage"] == "Closed Won"]
auxiliar_df["Stage_Won"] = auxiliar_df["Stage"] == "Closed Won"

# Agrupo segun region y sus cantidades de Stages y Stages_Won
casos_segun_region = auxiliar_df.groupby(["Region"]).agg({"Stage": "count", "Stage_Won" : "count"})
# Creo un Grafico
grafico_exito_segun_region = casos_segun_region.plot()

# Pongo titulo al grafico
grafico_exito_segun_region.set_title("Relacion entre cantidad Oportunidades y Oportunidades exitosas por Region")
# Pongo nombre al label x
grafico_exito_segun_region.set_xlabel("Region")
#Pongo nombre al laberl y
grafico_exito_segun_region.set_ylabel("Number of Oportunities")     

grafico_exito_segun_region
# Out:
# /home/fernando/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# <AxesSubplot:title={'center':'Relacion entre cantidad Oportunidades y Oportunidades exitosas por Region'}, xlabel='Region', ylabel='Number of Oportunities'>

# %% [markdown]
# # E) Analisis de porcentaje de exito segun si necesita o no codigo burocratico

# %%
#auxiliar = entrenamientoDf
#auxiliar["Necesita_Codigo"] = auxiliar[auxiliar["Bureaucratic_Code_0_Approval"] == 1]
#auxiliar["No_Necesita_Codigo"] = auxiliar[auxiliar["Bureaucratic_Code_0_Approval"] == 0]
#exito_segun_necesidad_codigo = auxiliar.groupby(["Stage"]).agg({"Necesita_Codigo" : "count","No_Necesita_Codigo" : "count" })
#exito = exito_segun_necesidad_codigo.drop(['Negotiation', 'Proposal',"Qualification"])
#exito.plot(kind="pie", subplots= True)

# %% [markdown]
# # F) Análisis de las ventas por tipo de producto

# %%
productType = entrenamientoDf['Product_Type']
productType.value_counts()
# Out:
# None              15935
# Other               515
# Product_Type_3      179
# Product_Type_1      142
# Product_Type_0       94
# Product_Type_4       73
# Product_Type_2        9
# Name: Product_Type, dtype: int64

# %% [markdown]
# No se puede hacer un análisis muy interesante de esta columna debido a la cantidad de valores en none que contiene.
